# %% [markdown]
# # Week 15 Programming Assignment
#
# The final thing for this semester that we haven't exercised, yet, is working with databases through Python.  In thi final assignment of the semester, you will practice pulling data from either Google Big Query or Snowflake, loading that data into a Pandas data frame, summarizing the data, and then exporting that to an Excel file.
#
# **You will need to use your own Google Big Query or Snowflake account to run this notebook, but you should try to make it configurable so anyone with an account in those technologies could run your notebook with minimal changes.**
#
#
# Build a notebook with good comments (either in code or in markdown cells).  Then submit your assignment as usual.

# %% [markdown]
# ### 1. Connect to the data source
#
# Follow the examples provided in the [week15 folder of our GitHub repository](https://github.com/paulboal/hds5210-2023/tree/main/week15) to connect your notebook either to Big Query or Snowflake.

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %% [markdown]
# ### 2. Query some data
#
# Assuming the source database has some data in it or that you can load some data into it from any source, query it.  Then, read that data into a Pandas dataframe.

# %%
# %%bigquery --project karthik-new-402519
# SELECT *
# FROM `karthik-new-402519.karthik_groupassignment.covidcommunityprofile`
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#        fips                      county states  fema_region  \
# 0      1000             Unallocated, AL     AL            4
# 1      2000             Unallocated, AK     AK           10
# 2      4000             Unallocated, AZ     AZ            9
# 3      5000             Unallocated, AR     AR            6
# 4      6000             Unallocated, CA     CA            9
# ...     ...                         ...    ...          ...
# 3289  39067         Harrison County, OH     OH            5
# 3290  39081        Jefferson County, OH     OH            5
# 3291  30007       Broadwater County, MT     MT            8
# 3292  30043        Jefferson County, MT     MT            8
# 3293  30049  Lewis and Clark County, MT     MT            8
#
#                           date  cases_last_7_days  cases_per_100k_last_7_days  \
# 0    2023-05-10 00:00:00+00:00                  0                         NaN
# 1    2023-05-10 00:00:00+00:00                  0                         NaN
# 2    2023-05-10 00:00:00+00:00                  0                         NaN
# 3    2023-05-10 00:00:00+00:00                  0                         NaN
# 4    2023-05-10 00:00:00+00:00                  1                         NaN
# ...                        ...                ...                         ...
# 3289 2023-05-10 00:00:00+00:00                  2                      13.298
# 3290 2023-05-10 00:00:00+00:00                 17                      26.024
# 3291 2023-05-10 00:00:00+00:00                  0                       0.000
# 3292 2023-05-10 00:00:00+00:00                  3                      24.548
# 3293 2023-05-10 00:00:00+00:00                 10                      14.403
#
#       total_cases  cases_pct_change_from_prev_week  deaths_last_7_days  ...  \
# 0               0                              NaN                   0  ...
# 1               6                              NaN                   0  ...
# 2               0                              NaN                   0  ...
# 3               0                              NaN                   0  ...
# 4            4322                           -0.889                   0  ...
# ...           ...                              ...                 ...  ...
# 3289         4207                           -0.333                   0  ...
# 3290        19029                            0.133                   0  ...
# 3291         1557                              NaN                   0  ...
# 3292         3197                              NaN                   0  ...
# 3293        22102                            0.111                   0  ...
#
#       pct_icu_beds_used_avg_last_7_days  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 3289                              0.493
# 3290                              0.493
# 3291                              0.407
# 3292                              0.407
# 3293                              0.407
#
#       pct_icu_beds_used_abs_change_from_prev_week  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 3289                                       -0.136
# 3290                                       -0.136
# 3291                                        0.022
# 3292                                        0.022
# 3293                                        0.022
#
#       pct_icu_beds_used_covid_avg_last_7_days  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 3289                                    0.007
# 3290                                    0.007
# 3291                                    0.128
# 3292                                    0.128
# 3293                                    0.128
#
#       pct_icu_beds_used_covid_abs_change_from_prev_week  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3289                                             -0.064
# 3290                                             -0.064
# 3291                                              0.128
# 3292                                              0.128
# 3293                                              0.128
#
#       pct_vents_used_avg_last_7_days  \
# 0                               None
# 1                               None
# 2                               None
# 3                               None
# 4                               None
# ...                              ...
# 3289                            None
# 3290                            None
# 3291                            None
# 3292                            None
# 3293                            None
#
#       pct_vents_used_abs_change_from_prev_week  \
# 0                                         None
# 1                                         None
# 2                                         None
# 3                                         None
# 4                                         None
# ...                                        ...
# 3289                                      None
# 3290                                      None
# 3291                                      None
# 3292                                      None
# 3293                                      None
#
#       pct_vents_used_covid_avg_last_7_days  \
# 0                                     None
# 1                                     None
# 2                                     None
# 3                                     None
# 4                                     None
# ...                                    ...
# 3289                                  None
# 3290                                  None
# 3291                                  None
# 3292                                  None
# 3293                                  None
#
#       pct_vents_used_covid_abs_change_from_prev_week  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# ...                                              ...
# 3289                                            None
# 3290                                            None
# 3291                                            None
# 3292                                            None
# 3293                                            None
#
#       pct_fully_vacc_total_pop  pct_fully_vacc_65_and_older
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
# ...                        ...                          ...
# 3289                     0.442                        0.786
# 3290                     0.518                        0.841
# 3291                     0.353                        0.668
# 3292                     0.530                        0.843
# 3293                     0.631                        0.932
#
# [3294 rows x 39 columns]

# %% [markdown]
# ### 3. Aggregate your data frame
#
# Do some kind of aggregation on your data frame.  Something that makes sense and has some groups to it.  Don't just sum up one column for the entire data frame.  Be more creative than that.

# %%
from google.cloud import bigquery
import pandas as pd

project_id = "karthik-new-402519"
client = bigquery.Client(project=project_id)

sql_query = """
SELECT *
FROM `karthik-new-402519.karthik_groupassignment.covidcommunityprofile`
"""
df = client.query(sql_query).to_dataframe()

agg_data = df.groupby('county')['states'].agg(['max', 'min']).reset_index()

agg_data.columns = ['county', 'max_value', 'min_value']

print(agg_data)
# Out:
#                     county max_value min_value
# 0     Abbeville County, SC        SC        SC
# 1        Acadia Parish, LA        LA        LA
# 2      Accomack County, VA        VA        VA
# 3           Ada County, ID        ID        ID
# 4         Adair County, IA        IA        IA
# ...                    ...       ...       ...
# 3288       Yuma County, AZ        AZ        AZ
# 3289       Yuma County, CO        CO        CO
# 3290     Zapata County, TX        TX        TX
# 3291     Zavala County, TX        TX        TX
# 3292    Ziebach County, SD        SD        SD
#
# [3293 rows x 3 columns]

# %% [markdown]
# ### 4. Write to Excel
#
# Use Pandas functions to write your summarized data out to a local Excel file.

# %%
agg_data.to_excel('agg_data.xlsx')

# %% [markdown]
# ---
#
# ## Submitting Your Work
#
# Submit your work as usual
